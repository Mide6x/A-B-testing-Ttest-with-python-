# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
from scipy.stats import ttest_ind

data = pd.read_csv('data.csv')

# %%
sns.distplot(data.Conversion_B)
# Out:
# C:\Users\Olumide Adewole\AppData\Local\Temp\ipykernel_4820\2826073765.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Conversion_B)
# <AxesSubplot:xlabel='Conversion_B', ylabel='Density'>

# %%
np.mean(data["Conversion_B"]) #mean for conversion B
# Out:
# 0.19333333333333336

# %%
np.mean(data["Conversion_A"]) #mean for conversion A
# Out:
# 0.162

# %%
t_stat, p_stat = ss.ttest_ind(data.Conversion_B, data.Conversion_A)
t_stat, p_stat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 t_stat, p_stat = ss.ttest_ind(data.Conversion_B, data.Conversion_A)
#       2 t_stat, p_stat
#
# NameError: name 'ss' is not defined
